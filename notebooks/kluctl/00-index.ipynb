# %% [markdown]
# # Kluctl
#
# A project with targets and Jinja2 over Kustomize, rendered offline the way CI does it.
#
# Every cell is a shell command, so the same steps work in a terminal. Run the notebooks in order; `/source/work` survives restarts.

# %% [markdown]
# <div style="display:grid;grid-template-columns:repeat(auto-fill,minmax(270px,1fr));gap:12px">
#   <a href="01-targets-and-rendering.ipynb" style="display:block;border:1px solid #8886;border-radius:6px;padding:12px 14px;text-decoration:none;color:inherit">
#     <div style="font-family:ui-monospace,SFMono-Regular,monospace;font-size:.72em;letter-spacing:.14em;text-transform:uppercase;opacity:.6">01</div>
#     <div style="font-weight:600;margin:.25em 0 .4em">Kluctl: targets and rendering</div>
#     <div style="font-size:.9em;opacity:.8;line-height:1.35">Kluctl is a deployment tool that wraps Kustomize deployments with targets, Jinja2 templating and a GitOps controller.</div>
#   </a>
# </div>

# %% [markdown]
# ## Exercises
#
# The prompts left in the notebooks, in one place.
#
# **[Kluctl: targets and rendering](01-targets-and-rendering.ipynb)**
#
# - add a second deployment item with its own tag and render only that tag.

# %% [markdown]
# [Back to all tracks](../00-start-here.ipynb)
