# %% [markdown]
# # ytt
#
# Carvel's structural templating: data values, Starlark annotations and overlays that patch YAML nodes instead of text.
#
# Every cell is a shell command, so the same steps work in a terminal. Run the notebooks in order; `/source/work` survives restarts.

# %% [markdown]
# <div style="display:grid;grid-template-columns:repeat(auto-fill,minmax(270px,1fr));gap:12px">
#   <a href="01-templates-and-overlays.ipynb" style="display:block;border:1px solid #8886;border-radius:6px;padding:12px 14px;text-decoration:none;color:inherit">
#     <div style="font-family:ui-monospace,SFMono-Regular,monospace;font-size:.72em;letter-spacing:.14em;text-transform:uppercase;opacity:.6">01</div>
#     <div style="font-weight:600;margin:.25em 0 .4em">ytt: templates and overlays</div>
#     <div style="font-size:.9em;opacity:.8;line-height:1.35">ytt (Carvel) templates YAML with Starlark annotations that respect the structure: values are data, overlays patch by matching nodes instead of text..</div>
#   </a>
# </div>

# %% [markdown]
# ## Exercises
#
# The prompts left in the notebooks, in one place.
#
# **[ytt: templates and overlays](01-templates-and-overlays.ipynb)**
#
# - add a data value for the ingress host and an overlay that applies it only in prod.

# %% [markdown]
# [Back to all tracks](../00-start-here.ipynb)
