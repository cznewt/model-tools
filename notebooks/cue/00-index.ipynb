# %% [markdown]
# # CUE
#
# Values, types and constraints, validating rendered manifests, contexts and rendering, Timoni modules and bundles, the mxc fleet model.
#
# Every cell is a shell command, so the same steps work in a terminal. Run the notebooks in order; `/source/work` survives restarts.

# %% [markdown]
# <div style="display:grid;grid-template-columns:repeat(auto-fill,minmax(270px,1fr));gap:12px">
#   <a href="01-cue-basics.ipynb" style="display:block;border:1px solid #8886;border-radius:6px;padding:12px 14px;text-decoration:none;color:inherit">
#     <div style="font-family:ui-monospace,SFMono-Regular,monospace;font-size:.72em;letter-spacing:.14em;text-transform:uppercase;opacity:.6">01</div>
#     <div style="font-weight:600;margin:.25em 0 .4em">CUE 01: values, types, constraints</div>
#     <div style="font-size:.9em;opacity:.8;line-height:1.35">In CUE a type is a value with more possibilities and a concrete value is the most specific type.</div>
#   </a>
#   <a href="02-import-and-schemas.ipynb" style="display:block;border:1px solid #8886;border-radius:6px;padding:12px 14px;text-decoration:none;color:inherit">
#     <div style="font-family:ui-monospace,SFMono-Regular,monospace;font-size:.72em;letter-spacing:.14em;text-transform:uppercase;opacity:.6">02</div>
#     <div style="font-weight:600;margin:.25em 0 .4em">CUE 02: importing YAML and validating manifests</div>
#     <div style="font-size:.9em;opacity:.8;line-height:1.35">`cue import` turns existing YAML or JSON into CUE; `cue vet -d '#Def' schema.cue data.yaml` checks data files against a definition without converting them.</div>
#   </a>
#   <a href="03-contexts-and-render.ipynb" style="display:block;border:1px solid #8886;border-radius:6px;padding:12px 14px;text-decoration:none;color:inherit">
#     <div style="font-family:ui-monospace,SFMono-Regular,monospace;font-size:.72em;letter-spacing:.14em;text-transform:uppercase;opacity:.6">03</div>
#     <div style="font-weight:600;margin:.25em 0 .4em">CUE 03: contexts and rendering in the companion repository</div>
#     <div style="font-size:.9em;opacity:.8;line-height:1.35">`examples/05-cue` describes the talk's workload: `schema.cue` is the context schema, `contexts.cue` the environments, `resources.cue` the workload as a function of the context, and `render_tool.cue` a `cue cmd` that writes YAML streams..</div>
#   </a>
#   <a href="04-timoni.ipynb" style="display:block;border:1px solid #8886;border-radius:6px;padding:12px 14px;text-decoration:none;color:inherit">
#     <div style="font-family:ui-monospace,SFMono-Regular,monospace;font-size:.72em;letter-spacing:.14em;text-transform:uppercase;opacity:.6">04</div>
#     <div style="font-weight:600;margin:.25em 0 .4em">CUE 04: Timoni modules and bundles</div>
#     <div style="font-size:.9em;opacity:.8;line-height:1.35">Timoni packages CUE as modules with a lifecycle (build, apply, upgrade, rollback) and distributes them as OCI artifacts.</div>
#   </a>
#   <a href="05-mxc.ipynb" style="display:block;border:1px solid #8886;border-radius:6px;padding:12px 14px;text-decoration:none;color:inherit">
#     <div style="font-family:ui-monospace,SFMono-Regular,monospace;font-size:.72em;letter-spacing:.14em;text-transform:uppercase;opacity:.6">05</div>
#     <div style="font-weight:600;margin:.25em 0 .4em">CUE 05: mxc, modelling the fleet</div>
#     <div style="font-size:.9em;opacity:.8;line-height:1.35">[epcim/mxc](https://github.com/epcim/mxc) sits one level above the other renderers: a typed model of `#Topology` -> `#Location` -> `#Cluster` -> `#App` from which adapters project Helm values, Kustomize overlays, Argo CD applications, Kluctl deployments, Compose files or Terraform variables.</div>
#   </a>
# </div>

# %% [markdown]
# ## Exercises
#
# The prompts left in the notebooks, in one place.
#
# **[CUE 01: values, types, constraints](01-cue-basics.ipynb)**
#
# - add a constraint that rejects an image without a registry host, then vet the contexts.
#
# **[CUE 02: importing YAML and validating manifests](02-import-and-schemas.ipynb)**
#
# - extend #Deployment so it requires a readiness probe and vet every rendered stream again.
#
# **[CUE 03: contexts and rendering in the companion repository](03-contexts-and-render.ipynb)**
#
# - add a staging context and render it; count the lines it cost.
#
# **[CUE 04: Timoni modules and bundles](04-timoni.ipynb)**
#
# - add a field to the module's #Config and build with a values file that omits it.
#
# **[CUE 05: mxc, modelling the fleet](05-mxc.ipynb)**
#
# - read one adapter under module/adapters and name which projections it feeds.

# %% [markdown]
# [Back to all tracks](../00-start-here.ipynb)
