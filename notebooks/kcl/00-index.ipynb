# %% [markdown]
# # KCL
#
# Schemas with check rules, kcl vet against plain data, kcl test, and the KCL renderer in the companion repository.
#
# Every cell is a shell command, so the same steps work in a terminal. Run the notebooks in order; `/source/work` survives restarts.

# %% [markdown]
# <div style="display:grid;grid-template-columns:repeat(auto-fill,minmax(270px,1fr));gap:12px">
#   <a href="01-schemas-and-checks.ipynb" style="display:block;border:1px solid #8886;border-radius:6px;padding:12px 14px;text-decoration:none;color:inherit">
#     <div style="font-family:ui-monospace,SFMono-Regular,monospace;font-size:.72em;letter-spacing:.14em;text-transform:uppercase;opacity:.6">01</div>
#     <div style="font-weight:600;margin:.25em 0 .4em">KCL: schemas and checks</div>
#     <div style="font-size:.9em;opacity:.8;line-height:1.35">KCL is a typed configuration language with schemas, defaults and `check` blocks, and it renders YAML directly.</div>
#   </a>
# </div>

# %% [markdown]
# ## Exercises
#
# The prompts left in the notebooks, in one place.
#
# **[KCL: schemas and checks](01-schemas-and-checks.ipynb)**
#
# - add a check rule that forbids the default namespace, then run kcl test.

# %% [markdown]
# [Back to all tracks](../00-start-here.ipynb)
