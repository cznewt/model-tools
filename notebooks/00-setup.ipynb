# %% [markdown]
# # model-tools notebooks
#
# These notebooks walk through the renderers compared in the talk *GitOps, from YAML to AI*,
# using the companion repository. Every cell is bash; the tools come from the model-tools image.
#
# Run the cells in order. `/source/work` is the persistent volume.

# %%
version

# %%
mkdir -p /source/work && cd /source/work && [ -d gitops-renderers ] || git clone --recurse-submodules https://github.com/cznewt/gitops-renderers.git
cd gitops-renderers && git log --oneline -3 && ls

# %%
cd /source/work/gitops-renderers
export TOOLS_LOCAL=1 SOPS_AGE_KEY_FILE=$PWD/examples/secrets/demo.agekey HOME=/tmp
just --list
